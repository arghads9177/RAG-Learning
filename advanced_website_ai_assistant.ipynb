# %% [markdown]
# # Advanced AI Assistant for An Website
#
# Scraping data using advanced loader (Unstructured Loader)

# %% [markdown]
# ### Loading Data from Website URLS

# %%
# Define the list of pages of sonfmeets.com website
page_list = [
    "https://softmeets.com/",
    "https://softmeets.com/automation/",
    "https://softmeets.com/internet-of-things/",
    "https://softmeets.com/artificial-intelligence/",
    "https://softmeets.com/analytics/",
    "https://softmeets.com/about-us/",
    "https://softmeets.com/customers/",
    "https://softmeets.com/partners/",
    "https://softmeets.com/contact-us/",
    "https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/",
    "https://softmeets.com/implementation-of-document-management-system-at-sail-bokaro-steel-plant/",
    "https://softmeets.com/application-development-system-modernization-and-support-upv-tms/",
    "https://softmeets.com/barqat/",
    "https://softmeets.com/rbms/",
    "https://softmeets.com/upv/",
    "https://softmeets.com/cms/",
    "https://softmeets.com/privacy-policy/"
]

# %%
# Import libraries
from unstructured.partition.html import partition_html
import requests
from langchain.schema import Document
from io import BytesIO

# %%
# Image filtering parameters
MIN_IMG_WIDTH = 100
MIN_IMG_HEIGHT = 100
EXCLUDE_KEYWORDS = ['logo', 'icon', 'favicon', 'social', 'profile', 'linkedin', 'twitter', 'facebook']

# %%
def is_valid_image(url):
    """Filter small/icon/logo images."""
    url_lower = url.lower()
    if any(kw in url_lower for kw in EXCLUDE_KEYWORDS):
        return False
    try:
        img = Image.open(BytesIO(requests.get(url, timeout=10).content))
        width, height = img.size
        return width >= MIN_IMG_WIDTH and height >= MIN_IMG_HEIGHT
    except:
        return False

# %%
documents = []
seen_texts = set()
seen_images = set()

for page in page_list:
    try:
        html = requests.get(page).text
        elements = partition_html(text=html)

        for el in elements:
            if el.category == 'Image' and el.metadata.image_url:
                image_url = el.metadata.image_url.strip()
                if image_url not in seen_images:
                    seen_images.add(image_url)
                    documents.append(Document(
                        page_content="",  # You will fill this later with OCR
                        metadata={"source": page, "image_url": image_url, "type": el.category}
                    ))

            elif el.category == "Table":
                table_content = el.metadata.text_as_html or el.text
                if table_content:
                    table_key = table_content.strip()
                    if table_key not in seen_texts:
                        seen_texts.add(table_key)
                        documents.append(Document(
                            page_content=table_key,
                            metadata={"source": page, "type": el.category}
                        ))

            elif el.category not in ["ListItem", "UncategorizedText"]:
                text = el.text.strip()
                if text and text not in seen_texts:
                    seen_texts.add(text)
                    documents.append(Document(
                        page_content=text,
                        metadata={"source": page, "type": el.category}
                    ))

    except Exception as e:
        print(f"[ERROR] Skipping page {page}: {e}")

# %%
len(documents)
# Out:
# 364

# %%
documents
# Out:
# [Document(metadata={'source': 'https://softmeets.com/', 'image_url': '//softmeets.com/wp-content/uploads/2024/11/soft-logo-1.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Your modernization journey starts here.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Make technology your growth partner, Optimize operations and improve efficiency.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Serving up transformation & modernization solutions using:'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/automation-icon.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Automation'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/world.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Internet of Things'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/artificial-intelligence-icon.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Artificial intelligence'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/doughnut.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Trusted by our Government of India customers.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'NarrativeText'}, page_content='Trusted by our esteemed Government of India customers, we deliver reliable, innovative solutions tailored to meet critical operational and strategic needs. Our commitment to excellence ensures robust performance, security, and compliance, fostering enduring partnerships built on trust and proven success.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Rail-logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Sail-logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Ministry-of-Communicationlogo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/indian-army-loo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/icmr-logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Housing-Board-logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/NIT_Durgapur-logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/West_Bengal-logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Transform your entire business to innovative digital business process'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Embrace cutting-edge automation, advanced analytics, and seamless integrations to optimize operations, improve decision-making, and deliver exceptional customer experiences.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/certified-4-2.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/certified-3-2.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/certified-2-2.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/certified-1-2.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Contact us'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Softmeets Office Address'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Important Link'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'NarrativeText'}, page_content='© 2005-2024, Softmeets. All Rights Reserved.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Automation.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Our automation solutions leverage advanced technology to perform tasks with minimal human intervention, enhancing efficiency, accuracy, and scalability. Softmeets streamlines workflows, reduces costs, and minimizes errors, all while enabling seamless 24/7 operations. By automating repetitive tasks, we empower organizations to allocate resources to strategic initiatives, enhance safety by managing hazardous processes, and ensure compliance through consistent and reliable execution.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='With real-time monitoring and predictive analytics, automation drives data-driven decision-making and operational agility, resulting in better productivity, customer satisfaction, and long-term sustainability.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Empowering Efficiency, Elevating Accuracy'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Increased-Efficiency.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Increased Efficiency'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Faster Execution: Automation completes tasks faster than manual efforts, reducing process cycle times.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='24/7 Operation: Automated systems can run continuously without breaks or downtime.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Streamlined Workflows: Reduces bottlenecks by automating sequential tasks.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Cost-Savings.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Cost Savings'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Reduced Labor Costs: Minimizes the need for repetitive manual work, allowing employees to focus on strategic tasks.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Lower Operational Costs: ptimizes resource usage, such as energy and materials, in industrial automation.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Error Reduction: Fewer errors mean lower costs associated with rework or waste.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Improved-Accuracy.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Improved Accuracy'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Minimized Human Errors: Automation eliminates mistakes caused by fatigue or oversight.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Consistent Quality: Ensures uniformity in task execution, enhancing product and service quality.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Enhanced-Productivity.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Enhanced Productivity'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Scalability: Easily handles increased workloads without hiring additional staff.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Task Prioritization: Frees up human workers to focus on creative and complex tasks.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Faster Decision-Making: Real-time data processing enables quicker responses.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Compliance-Reporting.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Better Compliance and Reporting'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Regulatory Compliance: Automated systems can be programmed to adhere to specific industry standards and regulations.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Audit Trails: Maintains detailed logs of all operations, making compliance reporting easier.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Data-Driven-Insights.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Data-Driven Insights'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Real-Time Monitoring: Sensors and software provide live data for analysis and decision-making.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Predictive Analytics: Automation tools can forecast trends and detect potential failures, improving planning.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Enhanced-Safety.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Enhanced Safety'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Risk Reduction: Automation can take over hazardous tasks, reducing risks to human workers.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Remote Monitoring: IoT and SCADA systems allow for remote oversight of dangerous operations.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Scalability-and-Flexibility.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Scalability and Flexibility'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Adaptability: Easily modify processes to handle new requirements or increased workloads.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Integration: Modern automation tools integrate seamlessly with existing systems.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Customer-Satisfaction.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Customer Satisfaction'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Faster Services: Quicker responses and deliveries improve customer experience.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Consistency: Ensures reliable service delivery, building customer trust.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Long-Term-Sustainability.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Long-Term Sustainability'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Energy Efficiency: Optimized processes consume less energy and reduce waste.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Eco-Friendly Solutions: Automated systems can comply with environmental standards more effectively.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Delivering Excellence Through Our Core Services'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/PROCESS-INSTRUMENTATION-1.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='PROCESS INSTRUMENTATION'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/CONDITION-MONITORING-1.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='CONDITION MONITORING'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/INDUSTRIAL-AUTOMATION-1.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='INDUSTRIAL AUTOMATION'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/ENERGY-MANAGEMENT-1.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='ENERGY MANAGEMENT'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/INDUSTRIAL-IOT-WIRELESS-1.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='INDUSTRIAL IOT & WIRELESS'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/CALIBRATION-SERVICE-1.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='CALIBRATION SERVICES'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/MACHINE-COMMUNICATION-1.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='MACHINE COMMUNICATION'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/RETRO-FITTING-PROJECTS-1.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='RETRO FITTING PROJECTS'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/water-tank-300x172.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Vetting of Detail Project Report of Automation of Drinking Water Project With National Institute of Technology (NIT, Durgapur)'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Application-Development-300x172.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Application Development, System Modernization and Support (UPV, TMS) for SAIL- IISCO'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/cable-management-300x172.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Cable Management System (CMS) in Indian Railways'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='The Cable Management System (CMS) in Indian Railways is a structured approach to organize, protect, and maintain the network of ...'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/rolling-300x172.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Rolling Block Management System (RBMS)'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='The Rolling Block Management System (RBMS) is an advanced system designed to manage train movements and track maintenance in a ...'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/upv-bg-300x172.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Implementation of UPV (Unified Plant View) of SAIL IISCO STEEL PLANT'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Want to know more about Softmeats?'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Internet-of-Things.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='With a holistic understanding, we can integrate systems, ranging from legacy to advanced smart systems. Our innovative Industrial IoT technology encompasses a range of features, including machine monitoring, asset tracking and predictive maintenance. This comprehensive suite of capabilities empowers you to reduce downtime, improve ROI, boost operational efficiency and maximize productivity. Through these advanced technologies, we aim to enhance your profitability by implementing cost-saving measures.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='The IoT ecosystem comprises of architectural components such as hardware, software, analytical components, connectivity layers and more. We have the expertise and resources necessary to deliver digital solutions that meet our client’s needs.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Industrial Benefits'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='Schedule maintenance of geographically distributed assets'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='Data driven analytics for timely informed decision-making'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Industrial-Benefits.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/integration.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Connected Devices'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='We design & develop IoT frameworks for registering, tracking, and monitoring devices at scale in diverse IoT deployments.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/saas.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Platform-as-a-Service'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='The platform is available as a software suite or a cloud service (PaaS) for users who need to monitor, control, or manage various types of endpoints remotely.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/feature-selection.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Vertical Application Platform'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='A universal platform designed to integrate algorithms for predictive maintenance of any industrial equipment from a centralized and live dashboard.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/iot.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='IoT Consulting Solution'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='Assist clients in transforming their business operations by adopting IoT technologies and helping them generate new value.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/analytic.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Intelligent Platforms'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='A multi-layer technology that allows managing entities closer with greater data processing and computing power.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/technology.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='End to End System Integration'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='We effectively integrate multiple IoT assets at the different stages of the product lifecycle to work cohesively and drive the best outcomes.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/artificial-intelligence.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='Softmeets integrating Artificial Intelligence (AI) technology into your existing application. The integration of AI has the potential to transform your legal operations by automating routine tasks, enhancing decision-making processes, and optimizing resource allocation. Our solution will empower your organization with cutting-edge tools for managing litigation cases more efficiently and with greater accuracy.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/robotic-process-automation.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Process Automation'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='Automate manual, repetitive tasks, reducing human error and freeing up resources for higher-value activities.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/data-driven.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Data-Driven Decision Making'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='Leverage AI algorithms to analyze historical and real-time data, providing actionable insights for improved decision-making.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/predictive-analysis.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Predictive Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='Use AI to predict trends, system failures, or resource needs, enabling preemptive actions that optimize performance.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/experience.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Enhanced User Experience'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='AI-driven personalization and automation can improve the usability of legacy systems, reducing the learning curve for end-users.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/cost-effective.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Cost Efficiency'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='AI integration extends the life of existing systems, avoiding the significant cost of system replacement while driving innovation.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/flexibility.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='AI enables legacy systems to adapt to changing needs and workflows, ensuring they remain relevant in an increasingly digital world.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Process'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/AI-0-1.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/pngtree-human-1.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Analytics.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Softmeets involved various analytics services that enable businesses and organizations to collect, process, analyze, and visualize data to drive informed decision-making. These services cater to various domains, including business intelligence, customer insights, operational efficiency, and predictive modeling.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Core Analytics Services'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Descriptive-Analytics.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Descriptive Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Understand historical data to determine trends and patterns.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Use Cases:'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Diagnostic-Analytics.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Diagnostic Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Investigate the reasons behind specific outcomes or trends.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Analyzing customer churn rates.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Identifying bottlenecks in workflows.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Predictive-Analytics.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Use statistical models and machine learning to forecast future outcomes.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Prescriptive-Analytics.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Prescriptive Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Recommend actions based on data insights.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Optimizing supply chain logistics.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Personalized marketing campaigns.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Real-Time-Analytics.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Real-Time Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Analyze data as it is generated for immediate insights.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Monitoring website activity in real-time.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Big-Data-Analytics.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Big Data Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Process and analyze massive datasets that exceed traditional database capacities.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Advanced-Analytics.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Advanced Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Implement advanced techniques like machine learning, natural language processing (NLP), and AI for deep insights.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Data-Visualization.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Data Visualization'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Key Benefits of Analytics Services'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/decision-making.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Improved Decision-Making'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/efficiency.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Enhanced Operational Efficiency'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/increase.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Increased Revenue'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Drives targeted marketing, upselling, and cross-selling opportunities.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/best-customer-experience.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Personalized Customer Experiences'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Delivers tailored solutions based on customer data.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/risk-management.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Risk Mitigation'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Predicts potential risks and enables proactive measures.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/innovation.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Scalable Solutions'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Supports growing data needs with scalable analytics platforms.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Technology Stack for Analytics Services'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Data-Storage-and-Processing.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Data Storage and Processing'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Data-Visualization-Tools.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Data Visualization Tools'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Machine-Learning-Platforms.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Machine Learning Platforms'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Big-Data-Technologies.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Big Data Technologies'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Application-solution.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Application solution'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Database-Solutions.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Database Solutions'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Why Choose Us for Analytics Services?'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Proven track record in delivering impactful insights.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='End-to-end analytics solutions tailored to your business needs.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Commitment to data privacy and compliance with regulations.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/why-choose-us.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/about-us/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/about-2.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/about-us/', 'type': 'Title'}, page_content='About the Softmeets'),
#  Document(metadata={'source': 'https://softmeets.com/about-us/', 'type': 'NarrativeText'}, page_content='When someone asks what we do softmeets Info Solutions, it’s tempting to point out our four-decade track record for helping to transform the world’s great companies into sharper, smarter, better versions of themselves. It’s true, our mission is to help management teams create such high levels of economic value that together we redefine our respective industries.'),
#  Document(metadata={'source': 'https://softmeets.com/about-us/', 'type': 'NarrativeText'}, page_content='We work with top executives to help them make better decisions, convert those decisions to actions, and deliver the sustainable success they desire. For forty years, we’ve been passionate about achieving better results for our clients-results that go beyond financial and are uniquely tailored, pragmatic, holistic, and enduring.'),
#  Document(metadata={'source': 'https://softmeets.com/about-us/', 'type': 'NarrativeText'}, page_content='We advise global leaders on their most critical issues and opportunities: strategy, marketing, organization, operations, technology, transformations and mergers & acquisitions, across all industries and geographies.'),
#  Document(metadata={'source': 'https://softmeets.com/about-us/', 'type': 'NarrativeText'}, page_content='Our unique approach to traditional change management, called Results Delivery, helps clients measure and manage risk and overcome the odds to realize results.'),
#  Document(metadata={'source': 'https://softmeets.com/about-us/', 'type': 'Title'}, page_content='Providing digital transformation, SaaS, Automation, Internet of Things, Artificial intelligence & Analytics technologies.'),
#  Document(metadata={'source': 'https://softmeets.com/customers/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/customer.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/customers/', 'type': 'Title'}, page_content='Our Customer'),
#  Document(metadata={'source': 'https://softmeets.com/customers/', 'type': 'NarrativeText'}, page_content="Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book."),
#  Document(metadata={'source': 'https://softmeets.com/customers/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/clw-indian-railways-logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/partners/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Partners.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/partners/', 'type': 'Title'}, page_content='Our Partners'),
#  Document(metadata={'source': 'https://softmeets.com/partners/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/hp.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/partners/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/12/microsoft-logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/partners/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/12/Schneider_Electric-Logo.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/partners/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/12/elnovapower_logo.jpg', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/contact-us/', 'type': 'Title'}, page_content='Contact Us'),
#  Document(metadata={'source': 'https://softmeets.com/contact-us/', 'type': 'Title'}, page_content='Get in touch with us!'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/water-tank.png', 'type': 'Image'}, page_content=''),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'NarrativeText'}, page_content="Vetting a Detailed Project Report (DPR) for the Automation of a Drinking Water Project with NIT Durgapur requires a systematic evaluation to ensure feasibility, accuracy, and alignment with project goals. Here's a structured guide for the vetting process."),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='Components to Check in the DPR'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='A. Executive Summary'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='B. Technical Feasibility'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='Financial Feasibility'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='Environmental and Social Impact'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='Implementation Plan'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='Recommendations for Automation'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'NarrativeText'}, page_content='Given the context of a drinking water project:'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='Steps to Vet the DPR'),
#  Document(metadata={'source': 'https://softmeets.com/vetting-of-detail-project-report-of-automation-of-drinking-water-project-with-national-institute-of-technology-durgapur/', 'type': 'Title'}, page_content='Expected Deliverables'),
#  Document(metadata={'source': 'https://softmeets.com/implementation-of-document-management-system-at-sail-bokaro-steel-plant/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/DMS-post.png', 'type': 'Image'}, page_content=''),
# ...
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content="Softmeets Info Solutions Pvt. Ltd. may collect a child's name (first name and last initial), date of birth, email address or telephone number, and the child's parent's email address in order to provide notice to parents that Softmeets Info Solutions Pvt. Ltd. may contact their child for the purpose of providing the Services through SISX's for which their teacher has signed up for. Softmeets Info Solutions Pvt. Ltd. may collect personal information through the Services from a child under 13 where that student's school, district, and/or teacher has agreed to obtain parental consent for that child to use the Services and disclose personal information to Softmeets Info Solutions Pvt. Ltd., for the use and benefit of providing services through SISX s ."),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='If you are a teacher, you represent and warrant that you have permission and authorization from your school and/or district to use the Services, and for purposes of COPPA compliance, you represent and warrant that you are entering into these Terms on behalf of your school and/or district.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='You may be required to provide valid school credentials and a valid school email address to verify your identity in order to access and use certain features of the Services.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='If Softmeets Info Solutions Pvt. Ltd. comes to know if any learn personal information have been collected from a student under 13 other than pursuant to the above, or if Softmeets Info Solutions Pvt. Ltd. learns that a student under 13 has provided personal information beyond what Softmeets Info Solutions Pvt. Ltd. requests from he or she, Softmeets Info Solutions Pvt. Ltd. will delete that information as quickly as possible. If you believe that a student under 13 may have provided Softmeets Info Solutions Pvt. Ltd. personal information in violation of this paragraph, please contact Softmeets Info Solutions Pvt. Ltd. at info@SISX s.com'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='Softmeets Info Solutions Pvt. Ltd. receive and store any information you knowingly enter on the Services of SISX s , whether via computer, mobile phone, other wireless device, or that you provide to Softmeets Info Solutions Pvt. Ltd. in any other way. This information may include Personal Information such as your name, phone number, email address, photograph, and, in certain circumstances, your school affiliation, which is used to provide notifications to users via the Services of SISX s from a teacher, school, and/or district ("alerts"), and any other information necessary for Softmeets Info Solutions Pvt. Ltd. to provide SISX S services.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Use of Information'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='User profile content shall be retained by Softmeets Info Solutions Pvt. Ltd. only as custodian of such information and data. That such information and data shall only be used by specific Users and not by Softmeets Info Solutions Pvt. Ltd. In order to facilitate interaction among Users of SISX S , other Users may share information with Users, or Users may be allowed to access certain information about other Users of SISX S . By entering into this Agreement, Users agree to treat information about other Users of SISX S strictly in accordance with the Agreement Softmeets Info Solutions Pvt. Ltd. may send push notifications to users who are students when their teacher has posted something new within the class to which they belong. If you no longer wish to receive such communications, you may turn them off at the device level. If you are a parent of a child who is under 13, you always have the choice to no longer allow your child to receive such communications by contacting us at info@SISX s.com. Any user may email Softmeets Info Solutions Pvt. Ltd. at info@sis.in, if such user no longer wishes to receive communications from the Services.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Data Integrity'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='We do not share, sell or rent users personally identifiable information to third parties. Softmeets Info Solutions Pvt. Ltd. will not share or distribute any user information with third parties except as provided below'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='When required to do so by law or regulation, or in response to a request from a law enforcement or governmental agency or authority or to establish or exercise our legal rights or defend against legal claims.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='In order to investigate, prevent, or take action regarding illegal activities, suspected fraud, situations involving potential threats to the physical safety of any person, violations of Softmeets Info Solutions Pvt. Ltd. terms of use, or as otherwise required by law.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='If Softmeets Info Solutions Pvt. Ltd. is acquired by or merged with another company. In this event, Softmeets Info Solutions Pvt. Ltd. will notify user about such merger and users being subjected to any different privacy policy'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='Not withstanding the above, Softmeets Info Solutions Pvt. Ltd. employ other companies and people to perform tasks on our behalf and may need to share your information with them (and for them to use that information) in order to provide aspects of our Services to you. Some examples of services for which we may use agents include sending email or SMS, analyzing data, and providing user services. These agents may use Personal Information we share with them, for example, to assist us, to provide their services to you and/or us, and to measure and improve the performance of their services. Softmeets Info Solutions Pvt. Ltd. may, work with third party websites to enhance your online experience, to send messages or letting you add "apps" to your account. We have no control over the policies and practices of third party websites or services as to privacy or anything else, so if you choose to allow the automatic transmissions discussed above, please review all third party websites\' or services\' policies before disclosing any Personal Information or other content on the Website or on any third party website or service'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Data Protection'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='Softmeets Info Solutions Pvt. Ltd. has adopted reasonable industry standard practices to ensure that there are adequate safeguards and techniques to protect the data of the user against any unauthorized or unlawful disclosure. Softmeets Info Solutions Pvt. Ltd. will not store, copy, disclose or use the data of the user except as necessary for the performance by Softmeets Info Solutions Pvt. Ltd. of its obligations under this Agreement. Softmeets Info Solutions Pvt. Ltd. employs physical, electronic and procedural safeguards to protect the information we receive from users from unauthorized disclosure. Softmeets Info Solutions Pvt. Ltd. limits access to personal information about user to employees of Softmeets Info Solutions Pvt. Ltd. who we believe reasonably need to come into contact with that information to provide services to users or in order to do their jobs. Users should not share their password with anyone. In addition, if user suspect unauthorized access to its information, it is users responsibility to contact Softmeets Info Solutions Pvt. Ltd. immediately. Softmeets Info Solutions Pvt. Ltd. will never ask user to divulge its password in written or electronic communications. Please be aware that Internet data transmission is not always secure and Softmeets Info Solutions Pvt. Ltd. cannot warrant that information user transmit utilizing this site is secure, however, Softmeets Info Solutions Pvt. Ltd. will always make reasonable efforts to ensure the security of the data provided on SISX. However, we cannot guarantee the security of user account information. Unauthorized entry or use, hardware or software failure, and other factors may compromise the security of user information at any time.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Service Providers We may employ third-party companies and individuals due to the following reasons:'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='We want to inform users of this Service that these third parties have access to your Personal Information. The reason is to perform the tasks assigned to them on our behalf. However, they are obligated not to disclose or use the information for any other purpose.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Security'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='We value your trust in providing us your Personal Information, thus we are striving to use commercially acceptable means of protecting it. But remember that no method of transmission over the internet, or method of electronic storage is 100% secure and reliable, and we cannot guarantee its absolute security.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Links to Other Sites'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='This Service may contain links to other sites. If you click on a third-party link, you will be directed to that site. Note that these external sites are not operated by us. Therefore, we strongly advise you to review the Privacy Policy of these websites. We have no control over and assume no responsibility for the content, privacy policies, or practices of any third-party sites or services.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content="Deletion Of Information Or Data Once User provides relevant information, data on this website for creating its profile, the same can be unsubscribed by providing request to following email id info@SISX s.com. Please note that certain information may remain in Softmeets Info Solutions Pvt. Ltd. records, server logs and archives after deletion of your account. Softmeets Info Solutions Pvt. Ltd. retains this information for purposes such as diagnosing problems with the service and for auditing legal investigations, but reserves the right to delete this information in accordance with its standard business practices in effect from time to time. Further, information and other content you have provided may remain visible elsewhere to the extent such content was copied or stored by other users. For under age users with an account that is inactive for twelve months or more (meaning the account has not received a message through the Services in that time), Softmeets Info Solutions Pvt. Ltd. policy is to disable access to Personal Information associated with that account. If yours or your child's personal information changes, or if you no longer desire our Service, wish to refuse further contact by Softmeets Info Solutions Pvt. Ltd. with your child, you may review, correct, update, delete inaccuracies, request deletion of your child's information, or amend it by contacting us at info@SISX.in or by logging into your account. We will respond to your request as quickly as possible. We will retain yours or your child's information for as long as your account is active or as needed to provide Services. If you wish to cancel yours or your child's account or request that we no longer use the information to provide Services, contact us at info@SISX.in Note we will retain and use information, for example, to comply with our audit and legal obligations, to resolve disputes, and to enforce our agreements."),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content="Deletion Of Information Or Data To the best of Softmeets Info Solutions Pvt. Ltd.'s knowledge, all material published by Softmeets Info Solutions Pvt. Ltd. on SISX S is done with the full agreement of the copyright owners (be that Softmeets Info Solutions Pvt. Ltd. or another party). If you come across a situation where you suspect that this may not be the case, in accordance with the Digital Millennium Copyright Act (DMCA), or if you have any questions or concerns regarding privacy we ask that you contact:"),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content="Children's Privacy"),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='These Services do not address anyone under the age of 13. We do not knowingly collect personally identifiable information from children under 13. In the case we discover that a child under 13 has provided us with personal information, we immediately delete this from our servers. If you are a parent or guardian and you are aware that your child has provided us with personal information, please contact us so that we will be able to do necessary actions.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Changes to This Privacy Policy'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='We may update our Privacy Policy from time to time. Thus, you are advised to review this page periodically for any changes. We will notify you of any changes by posting the new Privacy Policy on this page. These changes are effective immediately after they are posted on this page'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='DETAILS FOR CONTACTING SOFTMEETS INFO SOLUTIONS PVT. LTD. Phone: +91 9434811929'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='Copyright © 2018, Softmeets Info Solutions Pvt. Ltd. Infotech Pvt. Ltd. and/or its subsidiaries. All rights reserved.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='If you have any questions or suggestions about our Privacy Policy, do not hesitate to contact us.')]

# %% [markdown]
# ### Process the Image to extract Text from it

# %%
# Import libraries
import cv2
import numpy as np
from PIL import Image
from io import BytesIO
import pytesseract
from urllib.parse import urlparse
from transformers import BlipProcessor, BlipForConditionalGeneration

# %%
# Load captioning model
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# %%
# Normalize the Image URL
def normalize_url(url):
    if url and not urlparse(url).scheme:
        return 'https:' + url  # Default to https
    return url

# %%
# Preprocess image before OCR
def preprocess_image_for_ocr(image):
    # Convert to grayscale
    gray = image.convert('L')

    # Convert to OpenCV format
    open_cv_image = np.array(gray)
    open_cv_image = cv2.cvtColor(open_cv_image, cv2.COLOR_GRAY2BGR)

    # Resize to improve OCR accuracy
    open_cv_image = cv2.resize(open_cv_image, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

    # Thresholding
    _, thresh = cv2.threshold(cv2.cvtColor(open_cv_image, cv2.COLOR_BGR2GRAY), 150, 255, cv2.THRESH_BINARY)

    return Image.fromarray(thresh)

# %%
# Extract text from the images
def extract_text_from_image_url(image_url):
    try:
        image_url = normalize_url(image_url)
        response = requests.get(image_url)
        image = Image.open(BytesIO(response.content)).convert("RGB")
        preprocessed_image = preprocess_image_for_ocr(image)
        ocr_text = pytesseract.image_to_string(preprocessed_image, config="--psm 6")
        return ocr_text.strip()
    except Exception as e:
        print(f"[OCR Error] {image_url} => {e}")
        return ""

# %%
def generate_caption(image):
    try:
        inputs = processor(image, return_tensors="pt")
        out = model.generate(**inputs)
        return processor.decode(out[0], skip_special_tokens=True)
    except:
        return None

# %%
ocr_image_docs = []

for doc in documents:
    if doc.metadata.get("type") == 'Image':
        image_url = doc.metadata.get("image_url")
        ocr_text = extract_text_from_image_url(image_url).strip()
        # Process image
        try:
            image = Image.open(BytesIO(requests.get(image_url).content)).convert('RGB')
            print(image_url)
        except Exception as e:
            print(f"[Image Reading Error] {image_url} => {e}")
            continue

        caption = generate_caption(image)

        if ocr_text and len(ocr_text) > 10:
            combined_text = f"OCR: {ocr_text}"
            if caption:
                combined_text += f"\nCaption: {caption}"
        else:
            combined_text = caption if caption else "Image with no readable text or caption"
        doc.page_content = combined_text
    ocr_image_docs.append(doc)
# Out:
# Bd
# [Image Reading Error] //softmeets.com/wp-content/uploads/2024/11/soft-logo-1.png => Invalid URL '//softmeets.com/wp-content/uploads/2024/11/soft-logo-1.png': No scheme supplied. Perhaps you meant https:////softmeets.com/wp-content/uploads/2024/11/soft-logo-1.png?
# orm,
# « s
# = a
# a e
# Giz an?
# https://softmeets.com/wp-content/uploads/2024/11/automation-icon.png
# TNS
#
# \ \ aN
#
# r\ —
# || \
# if /
# / | /
# f |
#
# / [4 c
# https://softmeets.com/wp-content/uploads/2024/11/world.png
# aS
# https://softmeets.com/wp-content/uploads/2024/11/artificial-intelligence-icon.png
# /
# a“
# a
# a a?
# https://softmeets.com/wp-content/uploads/2024/11/doughnut.png
# | by 2
# PO “sate My
# Mh gam day,
# ST a
# on 1! *
# att, et a
# ig NG cau oe <
# a AGS”,
# i + a
# |
# https://softmeets.com/wp-content/uploads/2024/11/Rail-logo.png
# S|
# https://softmeets.com/wp-content/uploads/2024/11/Sail-logo.png
# ||
# https://softmeets.com/wp-content/uploads/2024/11/Ministry-of-Communicationlogo.png
# INDIAN ARMY
# https://softmeets.com/wp-content/uploads/2024/11/indian-army-loo.png
# g
# https://softmeets.com/wp-content/uploads/2024/11/icmr-logo.png
# at
#
# Lge xe
# ge pN
# oe s\
# e e
# g
# un By
#
# Ow
#
# CAL HOUS
# https://softmeets.com/wp-content/uploads/2024/11/Housing-Board-logo.png
# ey
# ¥ «
# ¥, mF T
# La SOT nest
# Thiele 5
# h Ve to re '
# a pis mu bovaty =
# woe 4 t sf
# Me!
# on, Sere a
# Sry a ot
# poat., ey ar | er Tt
# * Veta gy
# https://softmeets.com/wp-content/uploads/2024/11/NIT_Durgapur-logo.png
# ; < oe
# a Ss 4
# https://softmeets.com/wp-content/uploads/2024/11/West_Bengal-logo.png
# CMMI MATURITY
# LEVEL 5
# CERTIFIED
# http://softmeets.com/wp-content/uploads/2024/11/certified-4-2.jpg
# ISO 27001:2013
# http://softmeets.com/wp-content/uploads/2024/11/certified-3-2.jpg
# ISO 20000-1:2018
# http://softmeets.com/wp-content/uploads/2024/11/certified-2-2.jpg
# ISO 9001:2015
# http://softmeets.com/wp-content/uploads/2024/11/certified-1-2.jpg
# |
# N 7
# N 1Q
# we 4
# Sp ok €¢.
# YY te se.
# Ne ry +6
# oo yA .
# PS Bett J V
# \
# \ =.=
# https://softmeets.com/wp-content/uploads/2024/11/Automation.jpg
# \ -ea
# https://softmeets.com/wp-content/uploads/2024/11/Increased-Efficiency.jpg
# «
# °
# é ——_
# . h ' - aan
# ian ed ee
# 3 tee ae at
# : eka ay,
# https://softmeets.com/wp-content/uploads/2024/11/Cost-Savings.jpg
# Taw ~~
# !
# https://softmeets.com/wp-content/uploads/2024/11/Improved-Accuracy.jpg
# . 4 ;
# ay 7 e' . A
# / o* o£ = mt } /
# irc *, oe bog lth FEE e
# - TN . y
# : Xu
# sal
# ~\
# https://softmeets.com/wp-content/uploads/2024/11/Enhanced-Productivity.jpg
# we /?>
# . 3
# =
# —
# https://softmeets.com/wp-content/uploads/2024/11/Compliance-Reporting.jpg
# S
# 2)
# a
# | a oy.
# by ie hf . sy .
# Nd 7 a
# NOM OS TA LAL.
# https://softmeets.com/wp-content/uploads/2024/11/Data-Driven-Insights.png
# é - & i. oe, )
# Ne 7a
# cai
#
# il y
# < ~a>
# https://softmeets.com/wp-content/uploads/2024/11/Enhanced-Safety.jpg
# t
# Q°©O
# ao (8) —H i aie -( i)
# “ . 7 \S * hii ie %
# \ Cena & ©) ne —_
# https://softmeets.com/wp-content/uploads/2024/11/Scalability-and-Flexibility.jpg
# . f
# 7 eR |
# c > -9 Ps 6 e " q
# « ty ~ an
# Yay.
# https://softmeets.com/wp-content/uploads/2024/11/Customer-Satisfaction.jpg
# > \
# eA “N
# TENG i.
# “=A 4
# = ae :
# => SS
# AN Zz S SS
# SS f S
# x |
# Ya i EN \
# Ye \ aN
# https://softmeets.com/wp-content/uploads/2024/11/Long-Term-Sustainability.png
# oe i _8
# >" Poy ‘a
# ‘ (7) “ !
# ™ y - 7G iG.
# aes cbs ae
# t . Le i”
# ; jum
# http://softmeets.com/wp-content/uploads/2024/11/PROCESS-INSTRUMENTATION-1.jpg
# Speed vy ah ~ ~
# Dea
# ¥ Bows ~
# { | y NX 1" a ,
# http://softmeets.com/wp-content/uploads/2024/11/CONDITION-MONITORING-1.jpg
# ie oe ee |
# A es “*
# me Ne
# http://softmeets.com/wp-content/uploads/2024/11/INDUSTRIAL-AUTOMATION-1.jpg
# §
# =
# http://softmeets.com/wp-content/uploads/2024/11/ENERGY-MANAGEMENT-1.jpg
# 1 oe |
# http://softmeets.com/wp-content/uploads/2024/11/INDUSTRIAL-IOT-WIRELESS-1.jpg
# ; : r i :
# http://softmeets.com/wp-content/uploads/2024/11/CALIBRATION-SERVICE-1.jpg
# Bin M _
# \ "s | |: , . “ °
# 7 ee:
# ) : et
# wt “4 = !
# ee
# http://softmeets.com/wp-content/uploads/2024/11/MACHINE-COMMUNICATION-1.jpg
# amit |
# — ti lye “ :
# ee Ws = | :
# ety
# http://softmeets.com/wp-content/uploads/2024/11/RETRO-FITTING-PROJECTS-1.jpg
# COM = COU] Sees =
# ton ton
# Sl oe oe oe oe | =====5
# https://softmeets.com/wp-content/uploads/2024/11/water-tank-300x172.png
# mp OS SS
# eect ASS
# SNK SS SS
# Pal ‘ a
# . . LES, 3
# . SR tm NY 7
# pe ISS ,
# wee ve SS :
# aaa =.
# oe pe “ ™~.
# SZ 2 “,
# 2 ; .
# https://softmeets.com/wp-content/uploads/2024/11/Application-Development-300x172.jpg
# 3| 2) a oc ag oe
# | : 5 wr | . :
# WW ff, ALT
# q . a
# i NY a : pi BT \ hs.
# | | eens
# https://softmeets.com/wp-content/uploads/2024/11/cable-management-300x172.png
# pike tin O . ar
# Sag | Joyal,
# eee Lo - ‘ Ere
# —~e a a a es 3
# ea &
# os TL Ulli wo
# = I
# Sgt Joon ess Fe
# https://softmeets.com/wp-content/uploads/2024/11/rolling-300x172.jpg
# ele] ele
# https://softmeets.com/wp-content/uploads/2024/11/upv-bg-300x172.jpg
# 5 Ould
# \\Y 74 e nor
# S gs
# “
# (% ( -
# => © wy
# . = \\\
# https://softmeets.com/wp-content/uploads/2024/11/Internet-of-Things.png
# @)
# NN CD) / 4 S
# --~E LY * &
# Pall
# 1. JIC 3
# L
# https://softmeets.com/wp-content/uploads/2024/11/Industrial-Benefits.png
# an) a ~
# ; \ Hl 1
# fioJ | ' \
# https://softmeets.com/wp-content/uploads/2024/11/integration.png
# \
# https://softmeets.com/wp-content/uploads/2024/11/saas.png
# e
# https://softmeets.com/wp-content/uploads/2024/11/feature-selection.png
# —ae
# =
# https://softmeets.com/wp-content/uploads/2024/11/iot.png
#
# https://softmeets.com/wp-content/uploads/2024/11/analytic.png
# Od
# \ :
# https://softmeets.com/wp-content/uploads/2024/11/technology.png
# ram C] OR
# | gibi
# fo g
# https://softmeets.com/wp-content/uploads/2024/11/artificial-intelligence.png
# = eC
# _() _—_/ eo
# on i Ne,
# aaa
# https://softmeets.com/wp-content/uploads/2024/11/robotic-process-automation.png
# <2
# https://softmeets.com/wp-content/uploads/2024/11/data-driven.png
#
# https://softmeets.com/wp-content/uploads/2024/11/predictive-analysis.png
# pe
# z
# https://softmeets.com/wp-content/uploads/2024/11/experience.png
# @ ”
# a%
# https://softmeets.com/wp-content/uploads/2024/11/cost-effective.png
# eg
# https://softmeets.com/wp-content/uploads/2024/11/flexibility.png
# i Data Collection and Pre-processing
# =
# Al Model Selection
# ———)
# Al Model Training and Development
# |
# System Integration
# Testing and Validation
# Security and Compliance
# a
# Deployment and Rollout
# —————SS—
# https://softmeets.com/wp-content/uploads/2024/11/AI-0-1.png
# ree)
# wg TS OR
# (7° foN
# 4 a. ‘
# ° c a
# an o
# » ny
# J / ; NG
# . ; 7 f A ° \ NA,
# w, way P yo . -
# cs stay .
# Fag a - 7
# https://softmeets.com/wp-content/uploads/2024/11/pngtree-human-1.png
# jn
# - ew FO
# \-: gst. J?
# a 8
# aa
# https://softmeets.com/wp-content/uploads/2024/11/Analytics.png
# _ aa bias
# sh am lites
# nd
# Fa Mae RS wy
# eo ie
# https://softmeets.com/wp-content/uploads/2024/11/Descriptive-Analytics.png
# SF et ee
# ~
# \ ; 2. a af : * P
# eee ae, x 4
# Sea 24 ef $ “ ae
# Soy : FE = ci
# Sk % ie <e —_ °
# SS ~~ °° ae ~ ~ ©
# <3, ~ Se NS SS ~ Hitters. _ / t
# G Se) -
# 2 Sa) iy
# Sa sS con
# vy SS = wee
# fv Rake ba.
# ok. “ip, ~~ hy.
# RE NN Oy - =
# a S , ms
# Oe =
# https://softmeets.com/wp-content/uploads/2024/11/Diagnostic-Analytics.jpg
# oe 1 we . — “@e .-
# EN aa
# ’ hy 7 dq \»
# f- = T a o a
# Ne ae
# Me we
# 7 + é Ne * a’ a = 7 = . ~ . ~~
# https://softmeets.com/wp-content/uploads/2024/11/Predictive-Analytics.png
# ge #**
# mj ae
# a . . \\
# fae a | iat ) ¢ \
# } “J O&
# e. = = ( XN
# https://softmeets.com/wp-content/uploads/2024/11/Prescriptive-Analytics.jpg
# i ty ZO=
# ae ES “Bed
# — = a>
# > Sm tat. oO
# Ow
# ; — ors OTT TT me
# https://softmeets.com/wp-content/uploads/2024/11/Real-Time-Analytics.jpg
# AY 7" aaN a) © eS . .
# oN ei. ell
# tf 98% a ee eee _
# et J . 7
# L ——- , —
# : ™ -
# oOo \ . v oO
# t+} a . le . » .
# iS. (( mabe § é - oO
# o* » - | \ , .
# *» } . 4 _ on
# ser ~ 707
# https://softmeets.com/wp-content/uploads/2024/11/Big-Data-Analytics.jpg
# & _
# en ae eel Te
# https://softmeets.com/wp-content/uploads/2024/11/Advanced-Analytics.jpg
# p) === fam — ve ' ° > ° . -
# © Stel fil, wy
# a : Lo is : : a _
# . noe . re i eT ee eg
# 8 a . Ln . ;
# nc.
# https://softmeets.com/wp-content/uploads/2024/11/Data-Visualization.jpg
# a - |
# |
# — a“
# https://softmeets.com/wp-content/uploads/2024/11/decision-making.png
# |
# @ 11
# https://softmeets.com/wp-content/uploads/2024/11/efficiency.png
# mal
# oN
# ae \
# a \
# we \
# a i
# a \
# we \
# a \
# ? \
# Z \
# v iy
# Jf \
# / ah
# v4
# c /
# tt “
# “
# https://softmeets.com/wp-content/uploads/2024/11/increase.png
# * wre
# https://softmeets.com/wp-content/uploads/2024/11/best-customer-experience.png
# C:
# https://softmeets.com/wp-content/uploads/2024/11/risk-management.png
# ry
# https://softmeets.com/wp-content/uploads/2024/11/innovation.png
# e a [ 4
# ‘ |
# . = PE ~
# : - 4c
# et “
# Bo fht DET RS
# 4 jie Sees .
# THE foocomese Get aoe ~
# se wee Si ee RS _
# , EERE cue |e Oo: .
# e . tye EVE TD MD @@ ®
# e e ® e "gts pl pug phen
# ee , Ce be ti 0S. aot ‘htt . ee oe
# ee ve “of ave Bape ig . e -
# safe LOT SB ete ae
# . -_ . 7. a" lnumtie . whe t ome - - m~
# Bade.» 2 Tw et viripre! >. if <9" s
# FR Ae ae r
# na ° : i . Vo Se oe
# ° ° eo. “e BY ° .
# . ° +
# ® @
# @ % x)
# http://softmeets.com/wp-content/uploads/2024/11/Data-Storage-and-Processing.jpg
# n j ' \ - =
# . f . : us
# . i ; - 52. | ery
# “ <i fog
# ae terres SN ~ wa
# , a rye grb me : a S
# tobe # vee
# L none a! goon ere cet
# Ys 4 oe ——_—
# ‘ — con —
# | > ens ——
# Bowl, _
# Biwe, .
# pees
# A oot ae.
# we SE
# “as HS -
# ~ mS)
# = : Ny oa
# a \ nll aaa a :
# - Nene TiAminw r
# SSF ee Yel ib ti bit Ze4 aan
# SC onah BNE PTE Aang
# ° Sets EZ ae /
# , ee Or ee:
# Sa ers
# ——e eo e
# soe @
# o b
# \P r Ne )
# http://softmeets.com/wp-content/uploads/2024/11/Data-Visualization-Tools.jpg
# Le CS) | | oo
# . @® o) G9 /,.
# “eGo.
# Sollee” 0
# area ©). : ® j Ej
# http://softmeets.com/wp-content/uploads/2024/11/Machine-Learning-Platforms.jpg
# _ feet “
# . y Oe cian ae
# ween ruts i Po ste “4
# A _ me | {MR ne
# -- aa ee | > Sl .
# — R | df. ian oF y : ba
# alu aoe eee
# eT Bein., E Sos!
# a" = oer
# we ~ _— a. © —
# \g Om ia we a: N 3 7 y An ‘ oe
# r = % } : : - rl - ~ : Pre ean : .
# vw e's reer. ;
# ~ : ~~ ae : -
# http://softmeets.com/wp-content/uploads/2024/11/Big-Data-Technologies.jpg
# : ¥ Se
# | ‘ _> Q .
# an
# Radet
# 9 mn avin
# Ko mpe
# py en an .
# ‘O) @ = m sbyte Soe aw
# ' ry si ‘ i wae «
# prvigned | ‘fel @
# d ase , ¥ aims (1S aee”
# j : : Mle: ee"
# f return t)
# .-, clude ¢ fay) srg
# z_ \ va! gate (int st ¥ qc a @
# 7 : oo
# t ast’
# ES, 2a
# . J Vv) ~ -_— =
# . L 7
# a> r) $ r
# http://softmeets.com/wp-content/uploads/2024/11/Application-solution.jpg
# 7 4 ae
# ie
# E cp | ° °
# ae
# = a
# , ~& =
# Vim |
# fo gg
# aT 4 _
# Sa :é
# http://softmeets.com/wp-content/uploads/2024/11/Database-Solutions.jpg
# 1%
#
# = 7), .
#
# _ © OF
# ma (@
#
# =" Se
# a i
# https://softmeets.com/wp-content/uploads/2024/11/why-choose-us.png
# et
# yee ory
# https://softmeets.com/wp-content/uploads/2024/11/about-2.jpg
# /home/argha-ds/datascience/ai-assistant/RAG/.venv/lib/python3.12/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# e ”*
# N hw
# Ve a | [ y
# /home/argha-ds/datascience/ai-assistant/RAG/.venv/lib/python3.12/site-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# https://softmeets.com/wp-content/uploads/2024/11/customer.png
# ! JENS: eg SME SYD): 3
# [lags ‘how
# ay fut | _/ ( ) ee LOs
#
# IGS eK: Sy
#
# eg Re OE ODN,
# Sa rl LEAS) co a ~
# https://softmeets.com/wp-content/uploads/2024/11/clw-indian-railways-logo.png
# 2
# a
# https://softmeets.com/wp-content/uploads/2024/11/Partners.jpg
# -
# https://softmeets.com/wp-content/uploads/2024/11/hp.png
#
# https://softmeets.com/wp-content/uploads/2024/12/microsoft-logo.png
#
# https://softmeets.com/wp-content/uploads/2024/12/Schneider_Electric-Logo.png
# ELNOMA
# https://softmeets.com/wp-content/uploads/2024/12/elnovapower_logo.jpg
# Roof Slab
# 200mm thick
# 700mm thick TM 4m |{ Sm | 4m [don | 4m
# SB ULC TUE ETERS IEEE RETR oe Gallery id cane imenpepnsameaiue an pany
# a ae tials inbatetelbtatataiatatattatet ie ata 110cam thick abl ) Tige twgpeeeeceremeres
# = — Floor Beam — LT Cofnma
# | (1000 *1000)anm Se Ve all 200 * 400}
# 3m 3n | >
# ros / Wall TNs
# —j—-— 200mm thick ——— MP) 2 neste GA
# EAT stam
# ; : SIA ev thick wall
# ° Cofuan = eA ee
# (600° 600}oum ST {|
# >, SISB IER CER IEe:. ery
# Bace Bean eI eS TTOmm thck
# ‘a (00 * 0} im SSS UT
# ITT TT pee
# => | SSL TL UT \__ Fleer Beam
# CCL I Ka (350 * $50) mu
# NN ry)
# . ~ \
# Minin
# om] (L__d,___J|___IL___Ib__1 | | | | ||
# dn 4n don da dn 4n dn dn dn dn
# https://softmeets.com/wp-content/uploads/2024/11/water-tank.png
# - ¢ rm [ b t vo
# fo i : oan I i a y °
# ; t mi J) heal P
# | sd : | aA ag 3 , = = <| Wu
# < 3 | Be | eZ 2.8 ee
# I ee ee
# j > ee" = ™ ‘Be S
# _—— - ' - i , SS -
# https://softmeets.com/wp-content/uploads/2024/11/DMS-post.png
# he
# >~ a
# —_—
# https://softmeets.com/wp-content/uploads/2024/11/DMS-post-80x80.png
# on ar SSg
# SS
# > TS
# https://softmeets.com/wp-content/uploads/2024/11/Application-Development-80x80.jpg
# CS
# ior.
# > BS
# https://softmeets.com/wp-content/uploads/2024/11/Domain-controlar-80x80.jpg
# pags }
# pie
# https://softmeets.com/wp-content/uploads/2024/11/IT-Security-80x80.png
# Se
# Be jt
# OL yy, 03
#
# * Ag
# https://softmeets.com/wp-content/uploads/2024/11/Digester-Recovery-80x80.jpg
# an oo OS 3 5
# am : ye ss. SSS
# SS bly: SSS.
# SsS0 > | ~N SS
# - ORR SY . SS NN
# PS NSS QA
# , Ss:
# ‘Ss
# . Y ‘se, SY
# - . SS Su 7 “SS —
# > > 7 Ry . y
# Ss . nd
# Sn OO, ~ | oo 4” .
# wo LF)" . -
# . 2 A CS e
# https://softmeets.com/wp-content/uploads/2024/11/Application-Development.jpg
# 4 f/f S$
# Gy by a
# Se Y
# NS _
# : o% a . | noe \
# » wor a :
# https://softmeets.com/wp-content/uploads/2024/11/Budget.jpg
# tie hs
# ul lhl .
# https://softmeets.com/wp-content/uploads/2024/11/rolling-80x80.jpg
# Deveson
# frat vrcaton h
# tn
# al a
# https://softmeets.com/wp-content/uploads/2024/11/drrms-80x80.jpg
#
# https://softmeets.com/wp-content/uploads/2024/11/cable-management-80x80.png
# Ne
# vy. A
# https://softmeets.com/wp-content/uploads/2024/11/Budget-80x80.jpg
# i a are fe . = - _
# rie Vg F } | _
# ° ‘ “wey Ty : med ’
# ® we z t ’
# - 7 ~~ " ions —e, ~ =
# v _*° ke. . ‘ a
# . Jy Ow ° . . y i
# ied san -e. }
# ‘ = _ . a 3s ee ay
# | ina *
# 2. Stock Graphical Analysis of
# ° 4
# + oe Sh , , 7 . e :
# J. :
# y = ——_
# | —————
# am we g
# “Ss = 3 . |
# = ;
# 7 >. i
# me =, : : ,
# te ~ “r. 2 2
# ry aC
# ° $.- ' '
# Aye | i i i ¢ ¢ ° : ; ; : | ; . a
# 7 4 ' P } ~, i] . : ‘ ‘ ‘ : + " “hours, = “4 os “ : ” 7 a = s : ; . u |
# . - ee
# fa = —_—_ “ ’ ~ we . = € | .
# a y : >, . . ' . 7
# of ob . ao i > . Se : wy" a >
# =" __ eee pe.
# é . — ream". Sy . S 2 ae fl at os we —_.. a —
# nae Se - s . CY rab “eg are > at ee a :, 5 Yad : ees sae . a
# RS ~ A Saryy hy yet pee te a weg peepee OE
# bab “Xi ‘ ied. tn “ay -o jOmnm 0 ewe Pal of ==. oe =" Dee ro oo at a Ray-wd : *
# » Xow he. o«, £6°'°Mn. « § bd) , ne 2 oe A tee en -— CEEOT Espen Pere
# https://softmeets.com/wp-content/uploads/2024/11/rolling.jpg
# 2
# : . 4 . 2 ty, J o
# wv we v a v - v - ~ ~ a . 7 _
# . 7 ° . . ° Ce ae er Cet ot he, ee ce
# SOL MACHONE SHTEO IMA, SPT VACHAE SPEED MMIN; SPT PROOAC THON HATE [TOA $2 PHOT THON WATE (SON)
# - ie S ii
# shave . . : . : .
# oe dia, won,
# = fay ~ STU eet SON ee eee
# : ag” S “,
# & a ' a - |
# 2 a: 7  ¥
# Baven Bates : : £ .
# - - v
# | 2 Bavew ca EA .
# Away Ateuts £ ° x
# af Bawes ma Bases ma _ .
# 21 AND “a0 Tew Par 2-30 Tempe
# SPT A NOBOK NOT 20 Th SPS-WINOBOK NO17-20 TOM BoNm EM EEL am
# tcc
# e t
# ccd -
# aos . Bi fae
# oats oy to6 ve
# , . ‘ : $00
# ay se pl whee * .
# gee a - wore . -
# Ov Py . wo ~ mone
# a4 ee oe a . ML Cg eae 8 Re ent Ae ee
# i id : we : Late et ws ras
# ve a re y Monte 5 ; .
# « u &
# te aad Ca ox oe we . = = x
# . - a
# -
# aw fy tee oe eae a - ?
# - <
# -
# ae
# BUNAER LEWEL
# https://softmeets.com/wp-content/uploads/2024/11/upv-bg.jpg
# WS I Te a _
# - K p " a a
# if )fe y a d =
# AP, AH
# wo ww y y : lil fie f {
# i i cog RIES —, g _ ;
# led o_O |
# |i ie Sort ee ai : °
# rif == a i
# 8
# _! ‘ I | o 4
# XI t Pt : —s PAY . sn an
# ——$fi-i- Liao ri oc 1 a ee ie ee
# an Ca  — EE a —— a a. 2 ae
# https://softmeets.com/wp-content/uploads/2024/11/cable-management.png

# %%
ocr_image_docs
# Out:
# [Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Your modernization journey starts here.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Make technology your growth partner, Optimize operations and improve efficiency.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Serving up transformation & modernization solutions using:'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/automation-icon.png', 'type': 'Image'}, page_content='OCR: orm,\n« s\n= a\na e\nGiz an?\nCaption: a computer with a gear wheel and a red gear wheel'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Automation'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/world.png', 'type': 'Image'}, page_content='OCR: TNS\n\n\\ \\ aN\n\nr\\ —\n|| \\\nif /\n/ | /\nf |\n\n/ [4 c\nCaption: a blue globe with three white dots'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Internet of Things'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/artificial-intelligence-icon.png', 'type': 'Image'}, page_content='a diagram of the human brain'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Artificial intelligence'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/doughnut.png', 'type': 'Image'}, page_content='OCR: /\na“\na\na a?\nCaption: a circle with a circle of colored circles'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Trusted by our Government of India customers.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'NarrativeText'}, page_content='Trusted by our esteemed Government of India customers, we deliver reliable, innovative solutions tailored to meet critical operational and strategic needs. Our commitment to excellence ensures robust performance, security, and compliance, fostering enduring partnerships built on trust and proven success.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Rail-logo.png', 'type': 'Image'}, page_content='OCR: | by 2\nPO “sate My\nMh gam day,\nST a\non 1! *\natt, et a\nig NG cau oe <\na AGS”,\ni + a\n|\nCaption: the logo for the university of texas'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Sail-logo.png', 'type': 'Image'}, page_content='a blue background with a white border'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Ministry-of-Communicationlogo.png', 'type': 'Image'}, page_content='a black square with a white border'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/indian-army-loo.png', 'type': 'Image'}, page_content='OCR: INDIAN ARMY\nCaption: indian army logo'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/icmr-logo.png', 'type': 'Image'}, page_content='the logo for the new york city council'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Housing-Board-logo.png', 'type': 'Image'}, page_content='OCR: at\n\nLge xe\nge pN\noe s\\\ne e\ng\nun By\n\nOw\n\nCAL HOUS\nCaption: the logo of the bangladesh bangladesh bank'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/NIT_Durgapur-logo.png', 'type': 'Image'}, page_content="OCR: ey\n¥ «\n¥, mF T\nLa SOT nest\nThiele 5\nh Ve to re '\na pis mu bovaty =\nwoe 4 t sf\nMe!\non, Sere a\nSry a ot\npoat., ey ar | er Tt\n* Veta gy\nCaption: the logo for the royal regiment"),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/West_Bengal-logo.png', 'type': 'Image'}, page_content='OCR: ; < oe\na Ss 4\nCaption: the logo for the bangladesh air force'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Transform your entire business to innovative digital business process'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Embrace cutting-edge automation, advanced analytics, and seamless integrations to optimize operations, improve decision-making, and deliver exceptional customer experiences.'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/certified-4-2.jpg', 'type': 'Image'}, page_content='OCR: CMMI MATURITY\nLEVEL 5\nCERTIFIED\nCaption: the logo for the cmm level 5 certification'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/certified-3-2.jpg', 'type': 'Image'}, page_content='OCR: ISO 27001:2013\nCaption: a blue and white background with the words certified'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/certified-2-2.jpg', 'type': 'Image'}, page_content='OCR: ISO 20000-1:2018\nCaption: iso 2000 - 2018 certified'),
#  Document(metadata={'source': 'https://softmeets.com/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/certified-1-2.jpg', 'type': 'Image'}, page_content='OCR: ISO 9001:2015\nCaption: a blue and white certificate with the words certified'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Contact us'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Softmeets Office Address'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'Title'}, page_content='Important Link'),
#  Document(metadata={'source': 'https://softmeets.com/', 'type': 'NarrativeText'}, page_content='© 2005-2024, Softmeets. All Rights Reserved.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Automation.jpg', 'type': 'Image'}, page_content='OCR: |\nN 7\nN 1Q\nwe 4\nSp ok €¢.\nYY te se.\nNe ry +6\noo yA .\nPS Bett J V\n\\\n\\ =.=\nCaption: a woman working on a computer with a light bulb above her head'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Our automation solutions leverage advanced technology to perform tasks with minimal human intervention, enhancing efficiency, accuracy, and scalability. Softmeets streamlines workflows, reduces costs, and minimizes errors, all while enabling seamless 24/7 operations. By automating repetitive tasks, we empower organizations to allocate resources to strategic initiatives, enhance safety by managing hazardous processes, and ensure compliance through consistent and reliable execution.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='With real-time monitoring and predictive analytics, automation drives data-driven decision-making and operational agility, resulting in better productivity, customer satisfaction, and long-term sustainability.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Empowering Efficiency, Elevating Accuracy'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Increased-Efficiency.jpg', 'type': 'Image'}, page_content='a woman using a laptop with a graph on the screen'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Increased Efficiency'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Faster Execution: Automation completes tasks faster than manual efforts, reducing process cycle times.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='24/7 Operation: Automated systems can run continuously without breaks or downtime.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Streamlined Workflows: Reduces bottlenecks by automating sequential tasks.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Cost-Savings.jpg', 'type': 'Image'}, page_content="OCR: «\n°\né ——_\n. h ' - aan\nian ed ee\n3 tee ae at\n: eka ay,\nCaption: a person holding a pen and stack of coins"),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Cost Savings'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Reduced Labor Costs: Minimizes the need for repetitive manual work, allowing employees to focus on strategic tasks.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Lower Operational Costs: ptimizes resource usage, such as energy and materials, in industrial automation.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Error Reduction: Fewer errors mean lower costs associated with rework or waste.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Improved-Accuracy.jpg', 'type': 'Image'}, page_content='a man holding a tablet with a document icon on it'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Improved Accuracy'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Minimized Human Errors: Automation eliminates mistakes caused by fatigue or oversight.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Consistent Quality: Ensures uniformity in task execution, enhancing product and service quality.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Enhanced-Productivity.jpg', 'type': 'Image'}, page_content="OCR: . 4 ;\nay 7 e' . A\n/ o* o£ = mt } /\nirc *, oe bog lth FEE e\n- TN . y\n: Xu\nsal\n~\\\nCaption: businessman hand touching graph graph on touch screen stock photo"),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Enhanced Productivity'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Scalability: Easily handles increased workloads without hiring additional staff.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Task Prioritization: Frees up human workers to focus on creative and complex tasks.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Faster Decision-Making: Real-time data processing enables quicker responses.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Compliance-Reporting.jpg', 'type': 'Image'}, page_content='OCR: we /?>\n. 3\n=\n—\nCaption: a person using a laptop with a check mark on the screen'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Better Compliance and Reporting'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Regulatory Compliance: Automated systems can be programmed to adhere to specific industry standards and regulations.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Audit Trails: Maintains detailed logs of all operations, making compliance reporting easier.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Data-Driven-Insights.png', 'type': 'Image'}, page_content='OCR: S\n2)\na\n| a oy.\nby ie hf . sy .\nNd 7 a\nNOM OS TA LAL.\nCaption: a person using a laptop computer'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Data-Driven Insights'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Real-Time Monitoring: Sensors and software provide live data for analysis and decision-making.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Predictive Analytics: Automation tools can forecast trends and detect potential failures, improving planning.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Enhanced-Safety.jpg', 'type': 'Image'}, page_content='OCR: é - & i. oe, )\nNe 7a\ncai\n\nil y\n< ~a>\nCaption: a person using a laptop with a lock on it'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Enhanced Safety'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Risk Reduction: Automation can take over hazardous tasks, reducing risks to human workers.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Remote Monitoring: IoT and SCADA systems allow for remote oversight of dangerous operations.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Scalability-and-Flexibility.jpg', 'type': 'Image'}, page_content='OCR: t\nQ°©O\nao (8) —H i aie -( i)\n“ . 7 \\S * hii ie %\n\\ Cena & ©) ne —_\nCaption: a person holding a tablet with icons and symbols'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Scalability and Flexibility'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Adaptability: Easily modify processes to handle new requirements or increased workloads.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Integration: Modern automation tools integrate seamlessly with existing systems.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Customer-Satisfaction.jpg', 'type': 'Image'}, page_content='OCR: . f\n7 eR |\nc > -9 Ps 6 e " q\n« ty ~ an\nYay.\nCaption: a person holding a smiley face with stars around it'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Customer Satisfaction'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Faster Services: Quicker responses and deliveries improve customer experience.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Consistency: Ensures reliable service delivery, building customer trust.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Long-Term-Sustainability.png', 'type': 'Image'}, page_content='OCR: > \\\neA “N\nTENG i.\n“=A 4\n= ae :\n=> SS\nAN Zz S SS\nSS f S\nx |\nYa i EN \\\nYe \\ aN\nCaption: a man in a suit holding a tablet with a chart on it'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Long-Term Sustainability'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Energy Efficiency: Optimized processes consume less energy and reduce waste.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='Eco-Friendly Solutions: Automated systems can comply with environmental standards more effectively.'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Delivering Excellence Through Our Core Services'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/PROCESS-INSTRUMENTATION-1.jpg', 'type': 'Image'}, page_content='OCR: oe i _8\n>" Poy ‘a\n‘ (7) “ !\n™ y - 7G iG.\naes cbs ae\nt . Le i”\n; jum\nCaption: a group of valves in a building'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='PROCESS INSTRUMENTATION'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/CONDITION-MONITORING-1.jpg', 'type': 'Image'}, page_content='OCR: Speed vy ah ~ ~\nDea\n¥ Bows ~\n{ | y NX 1" a ,\nCaption: the factory floor with a large number of machines'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='CONDITION MONITORING'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/INDUSTRIAL-AUTOMATION-1.jpg', 'type': 'Image'}, page_content='OCR: ie oe ee |\nA es “*\nme Ne\nCaption: a machine that is making a large amount of metal'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='INDUSTRIAL AUTOMATION'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/ENERGY-MANAGEMENT-1.jpg', 'type': 'Image'}, page_content='a person holding a light bulb in their hand'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='ENERGY MANAGEMENT'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/INDUSTRIAL-IOT-WIRELESS-1.jpg', 'type': 'Image'}, page_content='a man in a suit and tie with a laptop and a laptop with a cloud computing icon'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='INDUSTRIAL IOT & WIRELESS'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/CALIBRATION-SERVICE-1.jpg', 'type': 'Image'}, page_content='a man using a digital multimeter to measure the temperature of a vehicle'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='CALIBRATION SERVICES'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/MACHINE-COMMUNICATION-1.jpg', 'type': 'Image'}, page_content='OCR: Bin M _\n\\ "s | |: , . “ °\n7 ee:\n) : et\nwt “4 = !\nee\nCaption: a machine that is working on a piece of paper'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='MACHINE COMMUNICATION'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/RETRO-FITTING-PROJECTS-1.jpg', 'type': 'Image'}, page_content='OCR: amit |\n— ti lye “ :\nee Ws = | :\nety\nCaption: the cover of the book, the cover of the book, is shown in the image of a factory'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='RETRO FITTING PROJECTS'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/water-tank-300x172.png', 'type': 'Image'}, page_content='OCR: COM = COU] Sees =\nton ton\nSl oe oe oe oe | =====5\nCaption: a diagram of the tower with the top and bottom sections'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Vetting of Detail Project Report of Automation of Drinking Water Project With National Institute of Technology (NIT, Durgapur)'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Application-Development-300x172.jpg', 'type': 'Image'}, page_content='OCR: mp OS SS\neect ASS\nSNK SS SS\nPal ‘ a\n. . LES, 3\n. SR tm NY 7\npe ISS ,\nwee ve SS :\naaa =.\noe pe “ ™~.\nSZ 2 “,\n2 ; .\nCaption: a laptop with a glowing screen and a glowing screen'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Application Development, System Modernization and Support (UPV, TMS) for SAIL- IISCO'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/cable-management-300x172.png', 'type': 'Image'}, page_content='OCR: 3| 2) a oc ag oe\n| : 5 wr | . :\nWW ff, ALT\nq . a\ni NY a : pi BT \\ hs.\n| | eens\nCaption: a blueprinted image of a computer circuit'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Cable Management System (CMS) in Indian Railways'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='The Cable Management System (CMS) in Indian Railways is a structured approach to organize, protect, and maintain the network of ...'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/rolling-300x172.jpg', 'type': 'Image'}, page_content='OCR: pike tin O . ar\nSag | Joyal,\neee Lo - ‘ Ere\n—~e a a a es 3\nea &\nos TL Ulli wo\n= I\nSgt Joon ess Fe\nCaption: a col of pictures of construction workers'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Rolling Block Management System (RBMS)'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'NarrativeText'}, page_content='The Rolling Block Management System (RBMS) is an advanced system designed to manage train movements and track maintenance in a ...'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/upv-bg-300x172.jpg', 'type': 'Image'}, page_content='a screenshot of a computer screen with a bunch of graphs'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Implementation of UPV (Unified Plant View) of SAIL IISCO STEEL PLANT'),
#  Document(metadata={'source': 'https://softmeets.com/automation/', 'type': 'Title'}, page_content='Want to know more about Softmeats?'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Internet-of-Things.png', 'type': 'Image'}, page_content='OCR: 5 Ould\n\\\\Y 74 e nor\nS gs\n“\n(% ( -\n=> © wy\n. = \\\\\\\nCaption: a group of people using their devices to communicate with each other people'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='With a holistic understanding, we can integrate systems, ranging from legacy to advanced smart systems. Our innovative Industrial IoT technology encompasses a range of features, including machine monitoring, asset tracking and predictive maintenance. This comprehensive suite of capabilities empowers you to reduce downtime, improve ROI, boost operational efficiency and maximize productivity. Through these advanced technologies, we aim to enhance your profitability by implementing cost-saving measures.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='The IoT ecosystem comprises of architectural components such as hardware, software, analytical components, connectivity layers and more. We have the expertise and resources necessary to deliver digital solutions that meet our client’s needs.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Industrial Benefits'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='Schedule maintenance of geographically distributed assets'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='Data driven analytics for timely informed decision-making'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Industrial-Benefits.png', 'type': 'Image'}, page_content='OCR: @)\nNN CD) / 4 S\n--~E LY * &\nPall\n1. JIC 3\nL\nCaption: a person sitting at a table with a tablet and a robot on the screen'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/integration.png', 'type': 'Image'}, page_content="OCR: an) a ~\n; \\ Hl 1\nfioJ | ' \\\nCaption: a blue and purple icon of a gear wheel"),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Connected Devices'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='We design & develop IoT frameworks for registering, tracking, and monitoring devices at scale in diverse IoT deployments.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/saas.png', 'type': 'Image'}, page_content='the hands holding a gear wheel with a gear wheel in the middle'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Platform-as-a-Service'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='The platform is available as a software suite or a cloud service (PaaS) for users who need to monitor, control, or manage various types of endpoints remotely.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/feature-selection.png', 'type': 'Image'}, page_content='a clipboard with a check mark and a check mark'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Vertical Application Platform'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='A universal platform designed to integrate algorithms for predictive maintenance of any industrial equipment from a centralized and live dashboard.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/iot.png', 'type': 'Image'}, page_content='the top 10 logo'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='IoT Consulting Solution'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='Assist clients in transforming their business operations by adopting IoT technologies and helping them generate new value.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/analytic.png', 'type': 'Image'}, page_content='a laptop with gears and gears on it'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='Intelligent Platforms'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='A multi-layer technology that allows managing entities closer with greater data processing and computing power.'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/technology.png', 'type': 'Image'}, page_content='a gear wheel with a gearwheel and a gearwheel'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'Title'}, page_content='End to End System Integration'),
#  Document(metadata={'source': 'https://softmeets.com/internet-of-things/', 'type': 'NarrativeText'}, page_content='We effectively integrate multiple IoT assets at the different stages of the product lifecycle to work cohesively and drive the best outcomes.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/artificial-intelligence.png', 'type': 'Image'}, page_content='OCR: ram C] OR\n| gibi\nfo g\nCaption: a person looking at a smartphone with a brain scan on it'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='Softmeets integrating Artificial Intelligence (AI) technology into your existing application. The integration of AI has the potential to transform your legal operations by automating routine tasks, enhancing decision-making processes, and optimizing resource allocation. Our solution will empower your organization with cutting-edge tools for managing litigation cases more efficiently and with greater accuracy.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/robotic-process-automation.png', 'type': 'Image'}, page_content='OCR: = eC\n_() _—_/ eo\non i Ne,\naaa\nCaption: a hand holding a piece of a gear'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Process Automation'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='Automate manual, repetitive tasks, reducing human error and freeing up resources for higher-value activities.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/data-driven.png', 'type': 'Image'}, page_content='a diagram with a graph and a pie chart'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Data-Driven Decision Making'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='Leverage AI algorithms to analyze historical and real-time data, providing actionable insights for improved decision-making.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/predictive-analysis.png', 'type': 'Image'}, page_content='a computer screen with a magni and a magni on it'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Predictive Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='Use AI to predict trends, system failures, or resource needs, enabling preemptive actions that optimize performance.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/experience.png', 'type': 'Image'}, page_content='a woman with a light bulb above her head'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Enhanced User Experience'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='AI-driven personalization and automation can improve the usability of legacy systems, reducing the learning curve for end-users.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/cost-effective.png', 'type': 'Image'}, page_content='a clock and money bag with a dollar bag'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Cost Efficiency'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='AI integration extends the life of existing systems, avoiding the significant cost of system replacement while driving innovation.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/flexibility.png', 'type': 'Image'}, page_content='a hand holding a clock with arrows pointing up'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'NarrativeText'}, page_content='AI enables legacy systems to adapt to changing needs and workflows, ensuring they remain relevant in an increasingly digital world.'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'type': 'Title'}, page_content='Process'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/AI-0-1.png', 'type': 'Image'}, page_content='OCR: i Data Collection and Pre-processing\n=\nAl Model Selection\n———)\nAl Model Training and Development\n|\nSystem Integration\nTesting and Validation\nSecurity and Compliance\na\nDeployment and Rollout\n—————SS—\nCaption: a diagram showing the steps of the system'),
#  Document(metadata={'source': 'https://softmeets.com/artificial-intelligence/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/pngtree-human-1.png', 'type': 'Image'}, page_content='OCR: ree)\nwg TS OR\n(7° foN\n4 a. ‘\n° c a\nan o\n» ny\nJ / ; NG\n. ; 7 f A ° \\ NA,\nw, way P yo . -\ncs stay .\nFag a - 7\nCaption: a woman with a robotic head'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Analytics.png', 'type': 'Image'}, page_content='OCR: jn\n- ew FO\n\\-: gst. J?\na 8\naa\nCaption: people looking at a large screen with graphs and graphs'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Softmeets involved various analytics services that enable businesses and organizations to collect, process, analyze, and visualize data to drive informed decision-making. These services cater to various domains, including business intelligence, customer insights, operational efficiency, and predictive modeling.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Core Analytics Services'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Descriptive-Analytics.png', 'type': 'Image'}, page_content='OCR: _ aa bias\nsh am lites\nnd\nFa Mae RS wy\neo ie\nCaption: a man and woman looking at graphs on a computer screen'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Descriptive Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Understand historical data to determine trends and patterns.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Use Cases:'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Diagnostic-Analytics.jpg', 'type': 'Image'}, page_content='OCR: SF et ee\n~\n\\ ; 2. a af : * P\neee ae, x 4\nSea 24 ef $ “ ae\nSoy : FE = ci\nSk % ie <e —_ °\nSS ~~ °° ae ~ ~ ©\n<3, ~ Se NS SS ~ Hitters. _ / t\nG Se) -\n2 Sa) iy\nSa sS con\nvy SS = wee\nfv Rake ba.\nok. “ip, ~~ hy.\nRE NN Oy - =\na S , ms\nOe =\nCaption: two people working on laptops with graphs and graphs'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Diagnostic Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Investigate the reasons behind specific outcomes or trends.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Analyzing customer churn rates.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Identifying bottlenecks in workflows.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Predictive-Analytics.png', 'type': 'Image'}, page_content='OCR: oe 1 we . — “@e .-\nEN aa\n’ hy 7 dq \\»\nf- = T a o a\nNe ae\nMe we\n7 + é Ne * a’ a = 7 = . ~ . ~~\nCaption: a colorful abstract background'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Use statistical models and machine learning to forecast future outcomes.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Prescriptive-Analytics.jpg', 'type': 'Image'}, page_content='OCR: ge #**\nmj ae\na . . \\\\\nfae a | iat ) ¢ \\\n} “J O&\ne. = = ( XN\nCaption: a hand touching a touch screen with a blue background'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Prescriptive Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Recommend actions based on data insights.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Optimizing supply chain logistics.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Personalized marketing campaigns.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Real-Time-Analytics.jpg', 'type': 'Image'}, page_content='OCR: i ty ZO=\nae ES “Bed\n— = a>\n> Sm tat. oO\nOw\n; — ors OTT TT me\nCaption: a laptop with a colorful background and icons'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Real-Time Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Analyze data as it is generated for immediate insights.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Monitoring website activity in real-time.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Big-Data-Analytics.jpg', 'type': 'Image'}, page_content='OCR: AY 7" aaN a) © eS . .\noN ei. ell\ntf 98% a ee eee _\net J . 7\nL ——- , —\n: ™ -\noOo \\ . v oO\nt+} a . le . » .\niS. (( mabe § é - oO\no* » - | \\ , .\n*» } . 4 _ on\nser ~ 707\nCaption: a man touching a finger on a digital interface'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Big Data Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Process and analyze massive datasets that exceed traditional database capacities.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Advanced-Analytics.jpg', 'type': 'Image'}, page_content='OCR: & _\nen ae eel Te\nCaption: a man in a suit holding a tablet with graphs on it'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Advanced Analytics'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Purpose: Implement advanced techniques like machine learning, natural language processing (NLP), and AI for deep insights.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/Data-Visualization.jpg', 'type': 'Image'}, page_content="OCR: p) === fam — ve ' ° > ° . -\n© Stel fil, wy\na : Lo is : : a _\n. noe . re i eT ee eg\n8 a . Ln . ;\nnc.\nCaption: a set of graphs and graphs on a dark background"),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Data Visualization'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Key Benefits of Analytics Services'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/decision-making.png', 'type': 'Image'}, page_content='OCR: a - |\n|\n— a“\nCaption: a diagram with arrows pointing up to the center of a sphere'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Improved Decision-Making'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/efficiency.png', 'type': 'Image'}, page_content='a clock and a bar chart'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Enhanced Operational Efficiency'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/increase.png', 'type': 'Image'}, page_content='OCR: mal\noN\nae \\\na \\\nwe \\\na i\na \\\nwe \\\na \\\n? \\\nZ \\\nv iy\nJf \\\n/ ah\nv4\nc /\ntt “\n“\nCaption: a graph with an arrow pointing up to the top'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Increased Revenue'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Drives targeted marketing, upselling, and cross-selling opportunities.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/best-customer-experience.png', 'type': 'Image'}, page_content='a person giving a thumbs up with five stars above them'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Personalized Customer Experiences'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Delivers tailored solutions based on customer data.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/risk-management.png', 'type': 'Image'}, page_content='a shield with a yellow and red icon'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Risk Mitigation'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Predicts potential risks and enables proactive measures.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'https://softmeets.com/wp-content/uploads/2024/11/innovation.png', 'type': 'Image'}, page_content='a laptop with a light bulb on top of it'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Scalable Solutions'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'NarrativeText'}, page_content='Supports growing data needs with scalable analytics platforms.'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Technology Stack for Analytics Services'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Data-Storage-and-Processing.jpg', 'type': 'Image'}, page_content='OCR: e a [ 4\n‘ |\n. = PE ~\n: - 4c\net “\nBo fht DET RS\n4 jie Sees .\nTHE foocomese Get aoe ~\nse wee Si ee RS _\n, EERE cue |e Oo: .\ne . tye EVE TD MD @@ ®\ne e ® e "gts pl pug phen\nee , Ce be ti 0S. aot ‘htt . ee oe\nee ve “of ave Bape ig . e -\nsafe LOT SB ete ae\n. -_ . 7. a" lnumtie . whe t ome - - m~\nBade.» 2 Tw et viripre! >. if <9" s\nFR Ae ae r\nna ° : i . Vo Se oe\n° ° eo. “e BY ° .\n. ° +\n® @\n@ % x)\nCaption: a cloud computing cloud with a city in the background'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Data Storage and Processing'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Data-Visualization-Tools.jpg', 'type': 'Image'}, page_content="OCR: n j ' \\ - =\n. f . : us\n. i ; - 52. | ery\n“ <i fog\nae terres SN ~ wa\n, a rye grb me : a S\ntobe # vee\nL none a! goon ere cet\nYs 4 oe ——_—\n‘ — con —\n| > ens ——\nBowl, _\nBiwe, .\npees\nA oot ae.\nwe SE\n“as HS -\n~ mS)\n= : Ny oa\na \\ nll aaa a :\n- Nene TiAminw r\nSSF ee Yel ib ti bit Ze4 aan\nSC onah BNE PTE Aang\n° Sets EZ ae /\n, ee Or ee:\nSa ers\n——e eo e\nsoe @\no b\n\\P r Ne )\nCaption: a person holding a tablet with a diagram on it"),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Data Visualization Tools'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Machine-Learning-Platforms.jpg', 'type': 'Image'}, page_content='OCR: Le CS) | | oo\n. @® o) G9 /,.\n“eGo.\nSollee” 0\narea ©). : ® j Ej\nCaption: a circle with icons and symbols surrounding it'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Machine Learning Platforms'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Big-Data-Technologies.jpg', 'type': 'Image'}, page_content='OCR: _ feet “\n. y Oe cian ae\nween ruts i Po ste “4\nA _ me | {MR ne\n-- aa ee | > Sl .\n— R | df. ian oF y : ba\nalu aoe eee\neT Bein., E Sos!\na" = oer\nwe ~ _— a. © —\n\\g Om ia we a: N 3 7 y An ‘ oe\nr = % } : : - rl - ~ : Pre ean : .\nvw e\'s reer. ;\n~ : ~~ ae : -\nCaption: a man working on a laptop with a digital interface'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Big Data Technologies'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'image_url': 'http://softmeets.com/wp-content/uploads/2024/11/Application-solution.jpg', 'type': 'Image'}, page_content='OCR: : ¥ Se\n| ‘ _> Q .\nan\nRadet\n9 mn avin\nKo mpe\npy en an .\n‘O) @ = m sbyte Soe aw\n\' ry si ‘ i wae «\nprvigned | ‘fel @\nd ase , ¥ aims (1S aee”\nj : : Mle: ee"\nf return t)\n.-, clude ¢ fay) srg\nz_ \\ va! gate (int st ¥ qc a @\n7 : oo\nt ast’\nES, 2a\n. J Vv) ~ -_— =\n. L 7\na> r) $ r\nCaption: a digital screen with a digital pattern'),
#  Document(metadata={'source': 'https://softmeets.com/analytics/', 'type': 'Title'}, page_content='Application solution'),
# ...
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content="Softmeets Info Solutions Pvt. Ltd. may collect a child's name (first name and last initial), date of birth, email address or telephone number, and the child's parent's email address in order to provide notice to parents that Softmeets Info Solutions Pvt. Ltd. may contact their child for the purpose of providing the Services through SISX's for which their teacher has signed up for. Softmeets Info Solutions Pvt. Ltd. may collect personal information through the Services from a child under 13 where that student's school, district, and/or teacher has agreed to obtain parental consent for that child to use the Services and disclose personal information to Softmeets Info Solutions Pvt. Ltd., for the use and benefit of providing services through SISX s ."),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='If you are a teacher, you represent and warrant that you have permission and authorization from your school and/or district to use the Services, and for purposes of COPPA compliance, you represent and warrant that you are entering into these Terms on behalf of your school and/or district.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='You may be required to provide valid school credentials and a valid school email address to verify your identity in order to access and use certain features of the Services.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='If Softmeets Info Solutions Pvt. Ltd. comes to know if any learn personal information have been collected from a student under 13 other than pursuant to the above, or if Softmeets Info Solutions Pvt. Ltd. learns that a student under 13 has provided personal information beyond what Softmeets Info Solutions Pvt. Ltd. requests from he or she, Softmeets Info Solutions Pvt. Ltd. will delete that information as quickly as possible. If you believe that a student under 13 may have provided Softmeets Info Solutions Pvt. Ltd. personal information in violation of this paragraph, please contact Softmeets Info Solutions Pvt. Ltd. at info@SISX s.com'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='Softmeets Info Solutions Pvt. Ltd. receive and store any information you knowingly enter on the Services of SISX s , whether via computer, mobile phone, other wireless device, or that you provide to Softmeets Info Solutions Pvt. Ltd. in any other way. This information may include Personal Information such as your name, phone number, email address, photograph, and, in certain circumstances, your school affiliation, which is used to provide notifications to users via the Services of SISX s from a teacher, school, and/or district ("alerts"), and any other information necessary for Softmeets Info Solutions Pvt. Ltd. to provide SISX S services.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Use of Information'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='User profile content shall be retained by Softmeets Info Solutions Pvt. Ltd. only as custodian of such information and data. That such information and data shall only be used by specific Users and not by Softmeets Info Solutions Pvt. Ltd. In order to facilitate interaction among Users of SISX S , other Users may share information with Users, or Users may be allowed to access certain information about other Users of SISX S . By entering into this Agreement, Users agree to treat information about other Users of SISX S strictly in accordance with the Agreement Softmeets Info Solutions Pvt. Ltd. may send push notifications to users who are students when their teacher has posted something new within the class to which they belong. If you no longer wish to receive such communications, you may turn them off at the device level. If you are a parent of a child who is under 13, you always have the choice to no longer allow your child to receive such communications by contacting us at info@SISX s.com. Any user may email Softmeets Info Solutions Pvt. Ltd. at info@sis.in, if such user no longer wishes to receive communications from the Services.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Data Integrity'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='We do not share, sell or rent users personally identifiable information to third parties. Softmeets Info Solutions Pvt. Ltd. will not share or distribute any user information with third parties except as provided below'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='When required to do so by law or regulation, or in response to a request from a law enforcement or governmental agency or authority or to establish or exercise our legal rights or defend against legal claims.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='In order to investigate, prevent, or take action regarding illegal activities, suspected fraud, situations involving potential threats to the physical safety of any person, violations of Softmeets Info Solutions Pvt. Ltd. terms of use, or as otherwise required by law.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='If Softmeets Info Solutions Pvt. Ltd. is acquired by or merged with another company. In this event, Softmeets Info Solutions Pvt. Ltd. will notify user about such merger and users being subjected to any different privacy policy'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='Not withstanding the above, Softmeets Info Solutions Pvt. Ltd. employ other companies and people to perform tasks on our behalf and may need to share your information with them (and for them to use that information) in order to provide aspects of our Services to you. Some examples of services for which we may use agents include sending email or SMS, analyzing data, and providing user services. These agents may use Personal Information we share with them, for example, to assist us, to provide their services to you and/or us, and to measure and improve the performance of their services. Softmeets Info Solutions Pvt. Ltd. may, work with third party websites to enhance your online experience, to send messages or letting you add "apps" to your account. We have no control over the policies and practices of third party websites or services as to privacy or anything else, so if you choose to allow the automatic transmissions discussed above, please review all third party websites\' or services\' policies before disclosing any Personal Information or other content on the Website or on any third party website or service'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Data Protection'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='Softmeets Info Solutions Pvt. Ltd. has adopted reasonable industry standard practices to ensure that there are adequate safeguards and techniques to protect the data of the user against any unauthorized or unlawful disclosure. Softmeets Info Solutions Pvt. Ltd. will not store, copy, disclose or use the data of the user except as necessary for the performance by Softmeets Info Solutions Pvt. Ltd. of its obligations under this Agreement. Softmeets Info Solutions Pvt. Ltd. employs physical, electronic and procedural safeguards to protect the information we receive from users from unauthorized disclosure. Softmeets Info Solutions Pvt. Ltd. limits access to personal information about user to employees of Softmeets Info Solutions Pvt. Ltd. who we believe reasonably need to come into contact with that information to provide services to users or in order to do their jobs. Users should not share their password with anyone. In addition, if user suspect unauthorized access to its information, it is users responsibility to contact Softmeets Info Solutions Pvt. Ltd. immediately. Softmeets Info Solutions Pvt. Ltd. will never ask user to divulge its password in written or electronic communications. Please be aware that Internet data transmission is not always secure and Softmeets Info Solutions Pvt. Ltd. cannot warrant that information user transmit utilizing this site is secure, however, Softmeets Info Solutions Pvt. Ltd. will always make reasonable efforts to ensure the security of the data provided on SISX. However, we cannot guarantee the security of user account information. Unauthorized entry or use, hardware or software failure, and other factors may compromise the security of user information at any time.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Service Providers We may employ third-party companies and individuals due to the following reasons:'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='We want to inform users of this Service that these third parties have access to your Personal Information. The reason is to perform the tasks assigned to them on our behalf. However, they are obligated not to disclose or use the information for any other purpose.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Security'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='We value your trust in providing us your Personal Information, thus we are striving to use commercially acceptable means of protecting it. But remember that no method of transmission over the internet, or method of electronic storage is 100% secure and reliable, and we cannot guarantee its absolute security.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Links to Other Sites'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='This Service may contain links to other sites. If you click on a third-party link, you will be directed to that site. Note that these external sites are not operated by us. Therefore, we strongly advise you to review the Privacy Policy of these websites. We have no control over and assume no responsibility for the content, privacy policies, or practices of any third-party sites or services.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content="Deletion Of Information Or Data Once User provides relevant information, data on this website for creating its profile, the same can be unsubscribed by providing request to following email id info@SISX s.com. Please note that certain information may remain in Softmeets Info Solutions Pvt. Ltd. records, server logs and archives after deletion of your account. Softmeets Info Solutions Pvt. Ltd. retains this information for purposes such as diagnosing problems with the service and for auditing legal investigations, but reserves the right to delete this information in accordance with its standard business practices in effect from time to time. Further, information and other content you have provided may remain visible elsewhere to the extent such content was copied or stored by other users. For under age users with an account that is inactive for twelve months or more (meaning the account has not received a message through the Services in that time), Softmeets Info Solutions Pvt. Ltd. policy is to disable access to Personal Information associated with that account. If yours or your child's personal information changes, or if you no longer desire our Service, wish to refuse further contact by Softmeets Info Solutions Pvt. Ltd. with your child, you may review, correct, update, delete inaccuracies, request deletion of your child's information, or amend it by contacting us at info@SISX.in or by logging into your account. We will respond to your request as quickly as possible. We will retain yours or your child's information for as long as your account is active or as needed to provide Services. If you wish to cancel yours or your child's account or request that we no longer use the information to provide Services, contact us at info@SISX.in Note we will retain and use information, for example, to comply with our audit and legal obligations, to resolve disputes, and to enforce our agreements."),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content="Deletion Of Information Or Data To the best of Softmeets Info Solutions Pvt. Ltd.'s knowledge, all material published by Softmeets Info Solutions Pvt. Ltd. on SISX S is done with the full agreement of the copyright owners (be that Softmeets Info Solutions Pvt. Ltd. or another party). If you come across a situation where you suspect that this may not be the case, in accordance with the Digital Millennium Copyright Act (DMCA), or if you have any questions or concerns regarding privacy we ask that you contact:"),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content="Children's Privacy"),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='These Services do not address anyone under the age of 13. We do not knowingly collect personally identifiable information from children under 13. In the case we discover that a child under 13 has provided us with personal information, we immediately delete this from our servers. If you are a parent or guardian and you are aware that your child has provided us with personal information, please contact us so that we will be able to do necessary actions.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'Title'}, page_content='Changes to This Privacy Policy'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='We may update our Privacy Policy from time to time. Thus, you are advised to review this page periodically for any changes. We will notify you of any changes by posting the new Privacy Policy on this page. These changes are effective immediately after they are posted on this page'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='DETAILS FOR CONTACTING SOFTMEETS INFO SOLUTIONS PVT. LTD. Phone: +91 9434811929'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='Copyright © 2018, Softmeets Info Solutions Pvt. Ltd. Infotech Pvt. Ltd. and/or its subsidiaries. All rights reserved.'),
#  Document(metadata={'source': 'https://softmeets.com/privacy-policy/', 'type': 'NarrativeText'}, page_content='If you have any questions or suggestions about our Privacy Policy, do not hesitate to contact us.')]

# %% [markdown]
# ### Split the documents into chunks

# %%
# Import libraries
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size= 500, chunk_overlap= 50)

# %%
splitted_docs = splitter.split_documents(ocr_image_docs)

# %%
len(splitted_docs)
# Out:
# 399

# %% [markdown]
# ### Ingest in VectorDB

# %%
# import libraries
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma

# %%
embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
vector_db = Chroma.from_documents(
    documents = splitted_docs,
    embedding= embedding,
    collection_name="softmeets_web_info"
)

# %% [markdown]
# ### Retrieve data and generate answer

# %%
retriever = vector_db.as_retriever()

# %%
# Import Libraries
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o")

# %%
# Define Prompt Template
template ="""
You are an assistant for question-answering task. Use the following pieces of retrieved context for answering the question.
If you don't know the answer, just say you don't know, don't try to make up an answer.
Your answer should be to the point and consice.
Question: {question}
Context: {context}
"""
prompt = ChatPromptTemplate.from_template(template)

# %%
# Define RAG Chain
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ### Test RAG chain

# %%
rag_chain.invoke("Tell me about Softmeets")
# Out:
# 'Softmeets offers various analytics services that help businesses and organizations collect, process, analyze, and visualize data. These services are designed to enhance business intelligence, customer insights, operational efficiency, and predictive modeling.'

# %%
rag_chain.invoke("Tell me their Office address")
# Out:
# "I don't know."

# %%
rag_chain.invoke("Who are their clients?")
# Out:
# "I don't know who their clients are based on the provided context."

# %%
rag_chain.invoke("Any certfication do they have?")
# Out:
# 'They have the ISO 9001:2015 certification and CMMI Maturity Level 5 certification.'

# %%
rag_chain.invoke("Tell me about the UPV?")
# Out:
# 'UPV refers to the Unified Plant View, a system implemented at the SAIL IISCO Steel Plant.'

# %%
rag_chain.invoke("Which technologies they use?")
# Out:
# 'They use SaaS, Automation, Internet of Things (IoT), Artificial Intelligence (AI), and Analytics technologies.'

# %%
rag_chain.invoke("Which tech stack they use for App development?")
# Out:
# "I don't know."
